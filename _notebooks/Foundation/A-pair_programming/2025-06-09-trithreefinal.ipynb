# %% [raw]
# ---
# layout: post
# title: Trimester 3 Final Blog
# description: T3 final log
# type: issues
# comments: true
# permalink: /finalblog
# ---

# %% [markdown]
# <!-- :::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::: -->
# <!--   TOP HUB — 3-CARD BUTTON GRID                                      -->
# <!-- :::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::: -->
#
# <style>
#   :root{
#     --hub-radius:22px;
#     --hub-shadow:0 14px 30px rgba(0,0,0,0.15);
#     --hub-blur:14px;
#   }
#
#   .hub-grid{
#     width:100%;
#     max-width:1100px;
#     margin:0 auto 56px;
#     display:grid;
#     grid-template-columns:repeat(auto-fit,minmax(300px,1fr));
#     gap:28px;
#     box-sizing:border-box;
#     padding:0 4vw;
#     font-family:'Segoe UI',sans-serif;
#   }
#
#   .hub-card{
#     position:relative;
#     height:220px;
#     padding:30px 26px;
#     background:rgba(255,255,255,0.35);
#     border:3px solid rgba(255,255,255,0.65);
#     border-radius:var(--hub-radius);
#     backdrop-filter:blur(var(--hub-blur)) saturate(180%);
#     -webkit-backdrop-filter:blur(var(--hub-blur)) saturate(180%);
#     box-shadow:var(--hub-shadow);
#     text-decoration:none;
#     overflow:hidden;
#     transition:transform .35s cubic-bezier(.18,.89,.32,1.28), box-shadow .35s;
#     display:flex;
#     flex-direction:column;
#     justify-content:center;
#   }
#   .hub-card:hover{
#     transform:translateY(-10px) scale(1.04);
#     box-shadow:0 20px 46px rgba(0,0,0,0.18);
#   }
#   .hub-card::before{
#     content:'';
#     position:absolute;
#     inset:-70px -70px auto auto;
#     width:220px;height:220px;
#     background:#F59E0B;
#     opacity:.07;
#     transform:rotate(40deg);
#   }
#   .hub-card h3{
#     margin:0 0 10px;
#     font-size:1.35rem;
#     color:#F59E0B;
#   }
#   .hub-card p{margin:0;color:#334155;font-size:1.05rem;line-height:1.55;}
#   .hub-card .date-badge{
#     display:inline-block;
#     margin-bottom:8px;
#     padding:2px 10px;
#     border-radius:12px;
#     background:#FEF3C7;
#     color:#B45309;
#     font-size:0.85rem;
#     font-weight:600;
#   }
#
#   /* Placeholder style */
#   .placeholder{
#     background:rgba(255,255,255,0.15);
#     border-style:dashed;
#     cursor:default;
#   }
# </style>
#
# <div class="hub-grid">
#
#   <!-- Night at the Museum Button -->
#   <a href="http://127.0.0.1:4100/johanmascarenhas/nightatthemuseumjune"
#      target="_blank" class="hub-card">
#     <span class="date-badge">Jun&nbsp;9&nbsp;2025</span>
#     <h3>🏛️ Night at the Museum Reflection</h3>
#     <p>
#       Showcased <strong>MediPulse</strong> to students, parents &amp; guests at 7 PM,
#       gathered feedback via Google Forms, and earned extra-credit through a LinkedIn discussion.<br><br>
#       <em>Tap for a 1-minute recap.</em>
#     </p>
#   </a>
#
#   <!-- vCard Page Button -->
#   <a href="http://127.0.0.1:4100/johanmascarenhas/v-cardblog" target="_blank" class="hub-card">
#     <h3>📇 Digital&nbsp;vCard &amp; Contact Hub</h3>
#     <p>
#       Gradient “business-card” page featuring my photo, quick-connect QR codes, a downloadable
#       vCard, and one-click links to email, portfolio, LinkedIn, and GitHub.<br><br>
#       <em>Tap to explore &amp; download.</em>
#     </p>
#   </a>
#
#   <!-- Empty slot for a future link -->
# <!-- GitHub + Grade Prediction Log -->
# <a href="http://127.0.0.1:4100/johanmascarenhas/gradepredandgithub" target="_blank" class="hub-card">
#   <h3>📈 GitHub + Grade Predictor</h3>
#   <p>
#     Tracking my work syncing GitHub commit data with a machine learning-based
#     grade prediction tool. Documented challenges, progress screenshots, and current solutions.<br><br>
#     <em>Tap to see snapshots and live links.</em>
#   </p>
# </a>
#
#
# </div>
#
# <!-- :::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::: -->
# <!--   KEY INTERESTS & FAVORITE PROJECT — PARAGRAPHS                     -->
# <!-- :::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::: -->
#
# <div style="padding:0 4vw;max-width:1100px;margin:0 auto 64px;font-family:'Segoe UI',sans-serif;line-height:1.6;">
#
# <h1 style="color:#4F46E5;font-size:2rem;margin:0;">🔑 Key Interests</h1>
# <p style="font-size:1.05rem;margin-top:12px;">
#   Over the past year in my <strong>AP Computer Science Principles</strong> class,
#   I uncovered an enduring love of programming and plan to turn coding into a full-time career.
# </p>
#
# <h1 style="color:#16A34A;font-size:2rem;margin:40px 0 0;">🏆 Favorite Project</h1>
# <p style="font-size:1.05rem;margin-top:12px;">
#   My proudest achievement is
#   <a href="https://open-coding-society.github.io/MediPulse/" target="_blank"
#      style="color:#16A34A;font-weight:600;text-decoration:none;">MediPulse ↗</a>,
#   a hospital-analytics platform where I served as <strong>assistant scrum master</strong>
#   and full-stack developer.
# </p>
#
# <ul style="margin:16px 0 0 24px;font-size:1.05rem;">
#   <li>Guided workflow &amp; wrote essential front- and back-end code.</li>
#   <li>Built the core ML algorithm ranking hospitals by safety, experience, location, and adverse-event rate.</li>
#   <li>Designed an interactive map UI with location picker &amp; medical-issue filtering.</li>
#   <li>Developed a second ML pipeline that optimizes hospital YouTube videos (titles, thumbnails, tags, length).</li>
# </ul>
#
# </div>
#
# <!-- :::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::: -->
# <!--   BLOG TABLE — WIDE & MODERN                                        -->
# <!-- :::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::: -->
#
# <style>
#   /* Table + Trimester styles (unchanged except bullet tweaks) ----------*/
#   .blog-table{
#     width:100%;
#     max-width:1100px;
#     margin:0 auto 56px;
#     border-collapse:collapse;
#     font-family:'Segoe UI',sans-serif;
#   }
#   .blog-table th,
#   .blog-table td{
#     padding:14px 18px;
#     border-bottom:1px solid #E2E8F0;
#     vertical-align:top;
#   }
#   .blog-table thead th{
#     background:#EEF2FF;
#     color:#4F46E5;
#     font-size:1.12rem;
#     text-align:left;
#   }
#   .blog-table tr:hover td{background:#F8FAFF;}
#   .blog-table a.live-link{
#     color:#16A34A;
#     font-weight:600;
#     text-decoration:none;
#   }
#   .blog-table a.live-link:hover{text-decoration:underline;}
#   .blog-table .bullet-list{
#     margin:6px 0 0 18px;
#     padding:0;
#     list-style:disc;
#   }
#
#   .trimester-block{
#     max-width:1100px;
#     margin:36px auto 56px;
#     font-family:'Segoe UI',sans-serif;
#     line-height:1.6;
#   }
#   .trimester-block h2{margin:0 0 14px;color:#4F46E5;font-size:1.6rem;}
#   .trimester-block h3{margin:18px 0 6px;font-size:1.22rem;color:#0EA5E9;}
#   .trimester-block p,
#   .trimester-block li{font-size:1.05rem;color:#334155;}
#   .trimester-block ul{margin:6px 0 0 22px;}
# </style>
#
# <h1 style="color:#4F46E5;text-align:center;margin-bottom:24px;">📓 Blog: Project Overview &amp; Unique Contributions</h1>
#
# <table class="blog-table">
#   <thead>
#     <tr>
#       <th style="width:18%;">Project</th>
#       <th style="width:32%;">Purpose</th>
#       <th>My Contributions</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td><strong>DNHS Café</strong></td>
#       <td>Chat room where users earn “coffee points” redeemable for real drinks.</td>
#       <td>
#         <ul class="bullet-list">
#           <li><strong>Developed the frontend &amp; HTML for the chatroom.</strong></li>
#         </ul>
#       </td>
#     </tr>
#     <tr>
#       <td><strong>Travelor</strong></td>
#       <td>Helps travelers discover and manage vacation spots.</td>
#       <td>
#         <ul class="bullet-list">
#           <li><strong>Built an interactive map</strong> (add / remove / view / delete locations).</li>
#           <li>Integrated a chatbot &amp; 3-D globe navigator.</li>
#         </ul>
#       </td>
#     </tr>
#     <tr>
#       <td><strong>MediPulse</strong></td>
#       <td>
#         Optimizes hospitals’ social-media presence on YouTube.
#         <a class="live-link" href="https://open-coding-society.github.io/MediPulse/" target="_blank">Live ↗</a>
#       </td>
#       <td>
#         <ul class="bullet-list">
#           <li><strong>Assistant scrum master</strong> &amp; lead on toughest webpages + ML models.</li>
#           <li><strong>Built full backend ML pipeline</strong> &amp; interactive frontend.</li>
#           <li>Added an extra ML system for YouTube video optimization.</li>
#         </ul>
#       </td>
#     </tr>
#   </tbody>
# </table>
#
# <!-- ======= Trimester Reflection ===================================== -->
# <div class="trimester-block">
#   <h2>My Journey Through the Trimesters</h2>
#
#   <h3>Tri&nbsp;1</h3>
#   <p>
#     I got accustomed to coding platforms and tools and familiarized myself with <code>GitHub</code> for version control.
#     Although I was initially slow with projects and learning <code>VS Code</code> as my main IDE,
#     by the end of the trimester I could write basic <code>HTML</code> pages, minimal <code>JavaScript</code> functions and <code>Python</code> scripts,
#     and use GitHub for cloning, pushing, and committing code.
#   </p>
#
#   <h3>Tri&nbsp;2</h3>
#   <p>
#     I accelerated my workflow and deepened my knowledge of <code>JavaScript</code>, <code>Python</code>, and full-stack development principles.
#     I invested significant time in the <em>Travelor</em> project, building a frontend using <code>HTML/CSS</code> and DOM manipulation that connects
#     to a backend <code>Flask</code> API. I also learned how to structure routes, handle JSON data, and deploy my work using platforms like <code>Replit</code> and <code>Render</code>.
#   </p>
#
#   <h3>Tri&nbsp;3</h3>
#   <p>
#     For <em>MediPulse</em>, I developed and deployed two production-ready machine learning models:
#   </p>
#   <ul>
#     <li>
#       A score-prediction model in <code>scikit-learn</code> that ranks hospitals based on location, safety, experience, and adverse event rates.
#       It includes feature weighting, normalization, and logistic regression.
#     </li>
#     <li>
#       A 300-tree <code>RandomForestClassifier</code> that predicts YouTube video performance using title metadata and synonym augmentation
#       powered by <code>nltk</code> and <code>WordNet</code>.
#     </li>
#   </ul>
#   <p>
#     I also integrated a <code>Gemini Pro</code> API module to generate engagement strategies and created fully responsive frontend
#     components in <code>HTML/CSS</code> and <code>Tailwind</code> to interface with each backend service via <code>Flask</code> routes.
#   </p>
#
#   <h3>Team Contributions</h3>
#   <p>As an <strong>assistant scrum master</strong>, I:</p>
#   <ul>
#     <li>Shared my ML logic and code snippets, influencing Gavin Copley’s <code>edit_optimization.py</code> implementation.</li>
#     <li>Assisted Daksha Gowda and Thomas Bao in turning backend specs into Figma wireframes and functional UI mockups.</li>
#     <li>Led ideation sessions and collected usability feedback to enhance our UI/UX through structured iteration.</li>
#     <li>Collaborated with Gavin to manage GitHub Projects, enforce commit discipline, and run stand-ups for sprint accountability.</li>
#   </ul>
# </div>
# <!-- ======= /Trimester Reflection ==================================== -->
#
# <!-- :::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::: -->
# <!--   QUICK LINKS                                                       -->
# <!-- :::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::: -->
#
# <h2 style="color:#0EA5E9;text-align:center;margin-bottom:12px;">🔗 Quick Links</h2>
# <ul style="font-family:'Segoe UI',sans-serif;font-size:1.1rem;list-style:none;text-align:center;padding:0;">
#   <li style="margin:6px 0;">
#     <a href="https://github.com/j0hwan/johanmascarenhas/issues"
#        style="color:#EA580C;font-weight:600;text-decoration:none;">GitHub Issues ↗</a>
#   </li>
#   <li style="margin:6px 0;">
#     <a href="https://github.com/j0hwan"
#        style="color:#EA580C;font-weight:600;text-decoration:none;">GitHub Profile &amp; Commits ↗</a>
#   </li>
# </ul>

# %% [markdown]
# <!-- :::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::: -->
# <!--   HOMEWORK ARCHIVE —  PREMIUM GLASSMORPHIC GRID                     -->
# <!-- :::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::: -->
#
# <!-- ⚙️  GLOBAL STYLE BOOST  -->
# <style>
#   /* Root variables for quick color tweaks */
#   :root{
#     --radius:20px;
#     --blur:18px;
#     --card-opacity:0.30;
#     --shadow:0 12px 28px rgba(0,0,0,0.18);
#   }
#
#   /* Grid wrapper */
#   .homework-grid{
#     display:grid;
#     grid-template-columns:repeat(auto-fill,minmax(260px,1fr));
#     gap:26px;
#     margin-top:34px;
#   }
#
#   /* “Liquid-Glass” Cards */
#   .glass-card{
#     position:relative;
#     padding:28px 24px;
#     border-radius:var(--radius);
#     background:rgba(255,255,255,var(--card-opacity));
#     border:2px solid rgba(255,255,255,0.5);
#     backdrop-filter:blur(var(--blur)) saturate(180%);
#     -webkit-backdrop-filter:blur(var(--blur)) saturate(180%);
#     box-shadow:var(--shadow);
#     transition:transform .35s cubic-bezier(.18,.89,.32,1.28), box-shadow .35s;
#     text-decoration:none;
#     overflow:hidden;
#   }
#
#   .glass-card:hover{
#     transform:translateY(-10px) scale(1.06);
#     box-shadow:0 16px 38px rgba(0,0,0,0.22);
#   }
#
#   /* Shimmer highlight */
#   .glass-card::after{
#     content:'';
#     position:absolute;
#     top:-120%; left:-40%;
#     width:60%; height:260%;
#     background:linear-gradient(120deg,rgba(255,255,255,0.15) 0%,rgba(255,255,255,0.02) 60%);
#     transform:rotate(25deg);
#     transition:opacity .3s;
#   }
#   .glass-card:hover::after{opacity:0.6;}
#
#   /* Accent bar */
#   .glass-card .accent-bar{
#     position:absolute;
#     top:0;left:0;
#     width:100%;height:8px;
#     background:var(--accent,#4F46E5);
#     border-top-left-radius:calc(var(--radius) - 1px);
#     border-top-right-radius:calc(var(--radius) - 1px);
#   }
#
#   /* Typography tweaks */
#   .glass-card h3{
#     margin:18px 0 6px;
#     color:var(--accent);
#     font-size:1.25rem;
#     font-weight:700;
#     letter-spacing:0.3px;
#   }
#   .glass-card p{
#     margin:0;
#     color:#334155;
#     font-size:1rem;
#     font-weight:500;
#   }
# </style>
#
# <h1 style="color:#4F46E5;font-size:2rem;margin-bottom:0.6em;">📚 Homework Archive</h1>
# <p style="margin-top:0;font-size:1.05rem;">
#   Below is a numbered list of every homework assignment published so far.
#   Click any card to jump straight to the write-up.
# </p>
#
# <div class="homework-grid">
#
# <!-- 🔹 Homework Cards (change --accent per card) -->
#
# <a href="https://j0hwan.github.io/johanmascarenhas/Homework1" class="glass-card" style="--accent:#4F46E5;">
#   <span class="accent-bar"></span>
#   <h3>Homework 1</h3>
#   <p>Introduction & Setup</p>
# </a>
#
# <a href="https://j0hwan.github.io/johanmascarenhas/DigitalDivide" class="glass-card" style="--accent:#10B981;">
#   <span class="accent-bar"></span>
#   <h3>Homework 2</h3>
#   <p>Digital Divide</p>
# </a>
#
# <a href="https://j0hwan.github.io/johanmascarenhas/computingbias" class="glass-card" style="--accent:#EAB308;">
#   <span class="accent-bar"></span>
#   <h3>Homework 3</h3>
#   <p>Computing Bias</p>
# </a>
#
# <a href="https://j0hwan.github.io/johanmascarenhas/crowdsourcing" class="glass-card" style="--accent:#EC4899;">
#   <span class="accent-bar"></span>
#   <h3>Homework 4</h3>
#   <p>Crowdsourcing</p>
# </a>
#
# <a href="https://j0hwan.github.io/johanmascarenhas/legalandethical" class="glass-card" style="--accent:#0284C7;">
#   <span class="accent-bar"></span>
#   <h3>Homework 5</h3>
#   <p>Legal & Ethical</p>
# </a>
#
# <a href="https://j0hwan.github.io/johanmascarenhas/privacyrisk" class="glass-card" style="--accent:#0EA5E9;">
#   <span class="accent-bar"></span>
#   <h3>Homework 6</h3>
#   <p>Privacy Risk</p>
# </a>
#
# <a href="https://j0hwan.github.io/johanmascarenhas/stylingg" class="glass-card" style="--accent:#8B5CF6;">
#   <span class="accent-bar"></span>
#   <h3>Homework 7</h3>
#   <p>Styling</p>
# </a>
#
# <a href="https://j0hwan.github.io/johanmascarenhas/binarysearch" class="glass-card" style="--accent:#22C55E;">
#   <span class="accent-bar"></span>
#   <h3>Homework 8</h3>
#   <p>Binary Search</p>
# </a>
#
# <a href="https://j0hwan.github.io/johanmascarenhas/listss" class="glass-card" style="--accent:#F43F5E;">
#   <span class="accent-bar"></span>
#   <h3>Homework 9</h3>
#   <p>Lists</p>
# </a>
#
# <a href="https://j0hwan.github.io/johanmascarenhas/simulationandalgorithm" class="glass-card" style="--accent:#F59E0B;">
#   <span class="accent-bar"></span>
#   <h3>Homework 10</h3>
#   <p>Simulation & Algorithm</p>
# </a>
#
# <a href="https://j0hwan.github.io/johanmascarenhas/Bigo" class="glass-card" style="--accent:#10B981;">
#   <span class="accent-bar"></span>
#   <h3>Homework 11</h3>
#   <p>Big-O Analysis</p>
# </a>
#
# <a href="https://j0hwan.github.io/johanmascarenhas/Decide" class="glass-card" style="--accent:#F472B6;">
#   <span class="accent-bar"></span>
#   <h3>Homework 12</h3>
#   <p>Decide Algorithm</p>
# </a>
#
# <a href="https://j0hwan.github.io/johanmascarenhas/Binary" class="glass-card" style="--accent:#A855F7;">
#   <span class="accent-bar"></span>
#   <h3>Homework 13</h3>
#   <p>Binary Numbers</p>
# </a>
#
# <a href="https://j0hwan.github.io/johanmascarenhas/logicgate" class="glass-card" style="--accent:#22C55E;">
#   <span class="accent-bar"></span>
#   <h3>Homework 14</h3>
#   <p>Logic Gates</p>
# </a>
#
# <a href="https://j0hwan.github.io/johanmascarenhas/base64" class="glass-card" style="--accent:#0EA5E9;">
#   <span class="accent-bar"></span>
#   <h3>Homework 15</h3>
#   <p>Base-64 Encoding</p>
# </a>
#
# </div>
#
# <p style="margin-top:36px;font-size:1rem;color:#475569;font-weight:500;">
#   <em>Last updated: {{ page.date | date: "%B %-d, %Y" }}</em>
# </p>
#
# <!-- :::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::: -->
