# %% [raw]
# ---
# layout: post
# title: emojiblog
# description: emoji page
# type: issues
# comments: true
# permalink: /emojiblog
# ---

# %%
import emoji
print(emoji.emojize(":thumbs_up: This is very COOL! :grinning_face:"))
# Out:
# 👍 This is very COOL! 😀
