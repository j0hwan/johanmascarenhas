# %% [raw]
# ---
# layout: post
# title: V-Card
# description: virtual-card blog
# type: issues
# comments: true
# permalink: /v-cardblog
# ---

# %% [markdown]
# <!-- =====================  vCard PAGE  ===================== -->
# <div class="bg-gradient-to-br from-indigo-50 via-purple-50 to-white min-h-screen flex flex-col items-center justify-center p-8 space-y-12">
#
#   <!-- Profile Photo -->
#   <div class="w-64 h-64 rounded-3xl overflow-hidden shadow-2xl ring-4 ring-indigo-200 transform hover:scale-105 transition-transform duration-300">
#     <img src="{{ site.baseurl }}/images/me.jpg"
#          alt="Johan Mascarenhas profile photo"
#          class="w-full h-full object-cover object-center">
#   </div>
#
#   <!-- CARD WRAPPER -->
#   <div class="flex flex-col lg:flex-row gap-10 w-full max-w-6xl">
#
#   <!-- CONTACT CARD -->
#   <section class="flex-1 bg-white rounded-3xl border border-indigo-200 shadow-lg p-10 hover:shadow-2xl transition-shadow duration-300">
#       <h2 class="text-3xl font-extrabold text-gray-800 text-center mb-8">
#         Contact&nbsp;Information
#       </h2>
#
#       <ul class="space-y-4 text-gray-700">
#         <li>
#           <a href="mailto:johanmascarenhas.jm@gmail.com"
#              class="flex items-center gap-3 p-4 rounded-xl hover:bg-indigo-50 transition-colors duration-200">
#             <img src="https://img.icons8.com/color/28/gmail.png" alt="Gmail" class="w-7 h-7">
#             <span class="font-semibold">johanmascarenhas.jm@gmail.com</span>
#           </a>
#         </li>
#
#         <li>
#           <a href="{{ site.baseurl }}/"
#              class="flex items-center gap-3 p-4 rounded-xl hover:bg-indigo-50 transition-colors duration-200">
#             <img src="https://img.icons8.com/fluency/28/domain.png" alt="Website" class="w-7 h-7">
#             <span class="font-semibold">Portfolio Website</span>
#           </a>
#         </li>
#
#         <li>
#           <a href="https://www.linkedin.com/in/johan-mascarenhas-0a483832a/"
#              target="_blank"
#              class="flex items-center gap-3 p-4 rounded-xl hover:bg-indigo-50 transition-colors duration-200">
#             <img src="https://img.icons8.com/color/28/linkedin.png" alt="LinkedIn" class="w-7 h-7">
#             <span class="font-semibold">LinkedIn Profile</span>
#           </a>
#         </li>
#
#         <li>
#           <a href="https://github.com/j0hwan"
#              target="_blank"
#              class="flex items-center gap-3 p-4 rounded-xl hover:bg-indigo-50 transition-colors duration-200">
#             <img src="https://img.icons8.com/material-outlined/28/github.png" alt="GitHub" class="w-7 h-7">
#             <span class="font-semibold">GitHub Profile</span>
#           </a>
#         </li>
#       </ul>
#
#       <div class="pt-8 text-center">
#         <button onclick="downloadVCard()"
#                 class="bg-indigo-600 hover:bg-indigo-700 text-white font-bold py-3 px-8 rounded-xl shadow-md hover:shadow-lg transform hover:scale-105 transition-all duration-200">
#           📄&nbsp;Download&nbsp;vCard
#         </button>
#       </div>
#     </section>
#
#     <!-- QR-CODE CARD -->
#     <section class="flex-1 bg-white rounded-3xl border border-indigo-200 shadow-lg p-10 hover:shadow-2xl transition-shadow duration-300 flex flex-col items-center justify-center space-y-10">
#       <h2 class="text-3xl font-extrabold text-gray-800 text-center">
#         Quick&nbsp;Connect
#       </h2>
#
#       <!-- QR grid -->
#       <div class="flex flex-col gap-10 items-center">
#         <!-- vCard QR -->
#         <figure class="text-center space-y-2">
#           <div class="transform hover:scale-105 transition-transform duration-300">
#             <img src="{{ site.baseurl }}/images/vcard.png"
#                  alt="QR code linking to this vCard page"
#                  class="w-52 h-52 rounded-2xl shadow-lg border border-gray-200">
#           </div>
#           <figcaption class="text-sm font-medium text-gray-600">This&nbsp;Page</figcaption>
#         </figure>
#
#         <!-- Site QR -->
#         <figure class="text-center space-y-2">
#           <div class="transform hover:scale-105 transition-transform duration-300">
#             <img src="{{ site.baseurl }}/images/home.png"
#                  alt="QR code linking to portfolio website"
#                  class="w-52 h-52 rounded-2xl shadow-lg border border-gray-200">
#           </div>
#           <figcaption class="text-sm font-medium text-gray-600">Portfolio&nbsp;Website</figcaption>
#         </figure>
#       </div>
#     </section>
#
#   </div>
# </div>
#
# <!-- =====================  vCard DOWNLOAD SCRIPT  ===================== -->
# <script>
# function downloadVCard () {
#   const vCardData = `
# BEGIN:VCARD
# VERSION:3.0
# FN:Johan Mascarenhas
# EMAIL:johanmascarenhas.jm@gmail.com
# URL:https://www.linkedin.com/in/johan-mascarenhas-0a483832a/
# NOTE:Connect with me and explore my work!
# END:VCARD`.trim();
#
#   const blob = new Blob([vCardData], { type: 'text/vcard' });
#   const url  = URL.createObjectURL(blob);
#   const link = document.createElement('a');
#   link.href = url;
#   link.download = 'johan_mascarenhas.vcf';
#   document.body.appendChild(link);
#   link.click();
#   document.body.removeChild(link);
#   URL.revokeObjectURL(url);
# }
# </script>
