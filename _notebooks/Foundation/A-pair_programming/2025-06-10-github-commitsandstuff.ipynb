# %% [raw]
# ---
# layout: post
# title: Github and Grade Predict
# description: GitHub and Grade Predict
# type: issues
# comments: true
# permalink: /gradepredandgithub
# ---

# %% [markdown]
# <style>
#   /* ===== Grid Wrapper (wider layout) ===== */
#   .snap-grid {
#     max-width: 1200px;
#     margin: 0 auto 60px;
#     display: grid;
#     grid-template-columns: repeat(auto-fit, minmax(400px, 1fr));
#     gap: 32px;
#     font-family: 'Segoe UI', sans-serif;
#   }
#
#   /* ===== Image Card ===== */
#   .snap-card {
#     background: #FFFFFF;
#     border: 3px solid #E0E7FF;
#     border-radius: 20px;
#     box-shadow: 0 12px 28px rgba(0,0,0,0.10);
#     overflow: hidden;
#     transition: transform .35s cubic-bezier(.18,.89,.32,1.28), box-shadow .35s;
#   }
#   .snap-card:hover {
#     transform: translateY(-8px) scale(1.03);
#     box-shadow: 0 18px 40px rgba(0,0,0,0.18);
#   }
#   .snap-card img {
#     width: 100%;
#     height: 280px;
#     object-fit: cover;
#     display: block;
#     cursor: pointer;
#   }
#   .snap-card p {
#     padding: 16px 20px 22px;
#     margin: 0;
#     font-size: 1rem;
#     color: #334155;
#     line-height: 1.55;
#   }
#
#   /* ===== Link Cards ===== */
#   .link-deck {
#     max-width: 950px;
#     margin: 0 auto;
#     display: flex;
#     flex-direction: column;
#     gap: 20px;
#   }
#   .link-card {
#     display: flex;
#     align-items: center;
#     gap: 20px;
#     padding: 18px 24px;
#     background: rgba(255,255,255,0.35);
#     border: 3px solid rgba(255,255,255,0.6);
#     border-radius: 22px;
#     backdrop-filter: blur(12px) saturate(180%);
#     -webkit-backdrop-filter: blur(12px) saturate(180%);
#     box-shadow: 0 12px 28px rgba(0,0,0,0.12);
#     text-decoration: none;
#     transition: transform .35s cubic-bezier(.18,.89,.32,1.28), box-shadow .35s;
#   }
#   .link-card:hover {
#     transform: translateY(-6px) scale(1.04);
#     box-shadow: 0 18px 42px rgba(0,0,0,0.18);
#   }
#   .link-card .emoji {
#     font-size: 2rem;
#   }
#   .link-card span {
#     font-size: 1.05rem;
#     color: #1E293B;
#     font-weight: 600;
#   }
#   .link-card small {
#     display: block;
#     font-size: 0.9rem;
#     color: #475569;
#     font-weight: 500;
#   }
#
#   /* ===== Fullscreen Image Dialog ===== */
#   dialog::backdrop {
#     background: rgba(0, 0, 0, 0.75);
#   }
#   dialog {
#     border: none;
#     background: none;
#     padding: 0;
#     max-width: 90%;
#     max-height: 90%;
#   }
#   dialog img {
#     width: 100%;
#     height: auto;
#     border-radius: 12px;
#   }
# </style>
#
# <div class="snap-grid">
#
#   <!-- ghub1 -->
#   <div class="snap-card">
#     <img src="{{ site.baseurl }}/images/ghub1.png" alt="GitHub grade-predict snapshot 1" onclick="openImage(this)">
#     <p>
#       I’m currently unable to generate grade predictions because the data pull
#       from GitHub isn’t complete yet. I’ve requested assistance via Slack and
#       am working on a fix—updates coming soon!
#     </p>
#   </div>
#
#   <!-- ghub2 -->
#   <div class="snap-card">
#     <img src="{{ site.baseurl }}/images/ghub2.png" alt="GitHub grade-predict snapshot 2" onclick="openImage(this)">
#     <p>
#       This shows the current status of my GitHub repo: recent commits and the areas
#       I’m monitoring before the next data extraction.
#     </p>
#   </div>
#
# </div>
#
# <!-- Image Viewer Dialog -->
# <dialog id="fullscreenViewer" onclick="this.close()">
#   <img id="dialogImg" src="" alt="Full-size view">
# </dialog>
#
# <script>
#   function openImage(img) {
#     const viewer = document.getElementById('fullscreenViewer');
#     const dialogImg = document.getElementById('dialogImg');
#     dialogImg.src = img.src;
#     viewer.showModal();
#   }
# </script>
#
# <div class="link-deck">
#
#   <a href="https://github.com/j0hwan/johanmascarenhas/issues" target="_blank" class="link-card">
#     <span class="emoji">🗂️</span>
#     <div>
#       <span>GitHub Issues Board</span>
#       <small>Track every open task and discussion in my projects.</small>
#     </div>
#   </a>
#
#   <a href="https://pages.opencodingsociety.com/profile" target="_blank" class="link-card">
#     <span class="emoji">📊</span>
#     <div>
#       <span>Grade-Predict Prototype</span>
#       <small>Page where I’m integrating GitHub data & analytics.</small>
#     </div>
#   </a>
#
#   <a href="https://github.com/j0hwan" target="_blank" class="link-card">
#     <span class="emoji">👤</span>
#     <div>
#       <span>My GitHub Profile</span>
#       <small>Explore commits, pinned repositories, and contributions.</small>
#     </div>
#   </a>
#
# </div>
