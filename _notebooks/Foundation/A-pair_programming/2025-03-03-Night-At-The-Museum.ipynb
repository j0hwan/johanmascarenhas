# %% [raw]
# ---
# layout: post
# title: Night At the Museum
# description:  what I have done and accomplished TRI 2 comp sci
# comments: true
# permalink: /museum
# ---

# %% [markdown]
# **Night At the Museum notes/images**

# %% [markdown]
# ***CSP PROJECTS***
#
#
#
# **Travelor(our project)**
#
#
# <li><img src="images/travelor.jpeg" alt="Travelor"></li>
#
# **Resturant reviews**
#
# Different content and resturant locations in San Diego
#
# You can find recipes for any specific place
#
# You can make reviews
#
# You have many tabs on the Website like San Diego Asia and South America. You also have locations on a map with different restaurants. You can comment your own resturant locations
#
#  <li><img src="images/resturant.jpeg" alt="Resturant"></li>
#
#
#
# **Chess:**
#
# Yo can play a game of chess
#
# You can do to a place to check your moves and download a png file. You can upload it into an analysis feature you can move arrow keys to move through moves the player and removed features allow you to show the moves you played or if you make a Kai take you can remove that move. You can evaluate your moves.
#
#
#
# Feedback: very good website but in the png file you should en able to edit your moves I think that would be a very good update.
#
#
#
# <li><img src="images/pawnsy.jpeg" alt="Pawnsy"></li>
#
# <li><img src="images/pawnsy2.jpeg" alt="Pawnsy 2"></li>
#
#
#
# **Binary**
#
# Helps you learn about binary while supplying binary games and quizzes. With quizzes you can see previous attempts and try to work to get better quiz results. There is a leaderboard with binary games. You can see top scores to improve how competitive people are.  Binary trials, a series of two games where you play multiplayer with 1 other person. The game features two dots moving to each other at a slow speed. You have to answer the decade of a historical question about binary to get the correct answer.  This game requires teamwork so player ball on the left doesn’t collide with player ball on the right. You can also add a binary history event
#
# <li><img src="images/binary.jpeg" alt="Binary"></li>
#
# <li><img src="images/binary2.jpeg" alt="Binary 2"></li>
#
#
#
#
# **Project frostbyte:**
#
# Website is supposed to connect passions of camping to a national park that right for you. You can take a quiz to find the best national park to visit. There is a national parks place with each park, where you can rate it, review it, and post a comment and share experiences . An individual names Elliot yang connected Gemini to a chat box. When you type into the box it adds an ai response into a chat box.
#
# Team challenges: lack of communication because of commits in vs code. To try to not override anyone’s commits. Organization difficulties where working together as a team had many challenges like clarifying roles in team.
#
#
#
# **Holiday shopping:**
#
# Holiday giftinator (Amazon but you can’t buy stuff you suggest gifts)
#
# You can make an account and change username statistics like passwords etc.
#
# There are notifications that whose notifications people sent to you and you can also send notifications to other people. It works as a dm system. There is a shopping website to explore gifts. These things you select give you gift ideas. There is an AI chat bot which you can ask any question and get any answer.
#
# <li><img src="images/giftinator.jpeg" alt="Giftinator"></li>
#
# <li><img src="images/giftinator2.jpeg" alt="Giftinator 2"></li>
#
#
#
#
#
#
#
#
# **Legendary Motorsport;**
#  It’s a car social media site. For lovers can share and support each other. There a feature where you can get to your profile and post cars and add cars to a virtual garage. You can add vehicles, manage vehicles, edit vehicles and remove vehicles. Has a car chat to talk to anybody about cars. Separates into electric cares, and gas cars. You can add pictures and text. You can also get recommended cars  and the user can favorite it and view different cars. You can look at cars you want to buy and like.
#
#  <li><img src="images/motor.jpeg" alt="Motor"></li>
#
#
#
#
#
# **Prism:**
#
# It’s an ai powered social media platform. Based on user interest. Get matched with people who like the same thing and you can discuss things the users like and have in common. Have features like chat rooms, there’s a daily question where you get questions based on your interest, and a daily poll where a user answers a daily poll based on their personal interests and other people who have the same interests. Lastly there is a leaderboard for top interests.
#
# <li><img src="images/prism.jpeg" alt="Prism"></li>
#
# <li><img src="images/prism2.jpeg" alt="Prism 2"></li>
#
#
#
#
#
# **Melody mates:**
#
# <li><img src="images/melodymates.jpeg" alt="Melody Mates"></li>
